# %% [markdown]
# <a href="https://colab.research.google.com/github/sureshsaripalle2004/audio-visual-traffic-anomaly-detection/blob/main/Audio_Visual_Traffic_Anomaly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mps project
